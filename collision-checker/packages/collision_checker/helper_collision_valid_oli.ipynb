# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
theta = 90 * np.pi / 180
R = np.array([[np.cos(theta), -np.sin(theta)],
                [np.sin(theta), np.cos(theta)]])

Pts = np.array([1, 0])
print(f"xpoints = \n{Pts}")

p = R @ Pts + np.array([1.2, 3.4])
print(f"xpoints = \n{p}")

min(np.linalg.norm(p-Pts), 0)
# Out:
# xpoints =
# [1 0]
# xpoints =
# [1.2 4.4]
# 0

# %%
xc,yc,radius = 1.9773044779003963,1.1417780597579434,0.7440571709914936
xr,yr,theta,xpoints, ypoints = 1.5041724683319224,1.2623376198409497,259.1215591392138,[-0.04986949167515502, 0.08761467971269997, 0.040433194665768786, -0.09705097672208621], [0.1114137953758943, 0.08499216374961283, -0.16051528515727106, -0.1340936535309896]
COLLISION=True

# %%
xpoints.append(xpoints[0])
ypoints.append(ypoints[0])
xpts = [x+xr for x in xpoints]
ypts = [y+yr for y in ypoints]

# %%
fig, ax = plt.subplots()

plt.title(f"detection={COLLISION}")
circle1 = plt.Circle((xc,yc),radius)
ax.add_patch(circle1)

ax.plot(xpts, ypts,color="red")   

ax.set_aspect('equal', adjustable='datalim')
ax.grid(visible=True)
plt.show()

# %%
#========= Rectangle vs Rectangle
#R1x,R1y,R1theta,R1xpts,R1ypts = 4.102880698465862,4.218503619078077,19.6743653957813,[-0.0705949467667147, -0.11772930718854673, 0.11767601025553003, 0.16481037067736204], [-0.09958088918565008, 0.03224608858303291, 0.11641458933630436, -0.015412388432378625]
#R2x,R2y,R2theta,R2xpts,R2ypts =  1.9409049100131248,4.073008023795881,309.88154456212254,[-0.3873221333045641, 0.1741664847859402, 0.3873221333045641, -0.1741664847859402], [-0.10703595470718086, 0.3621341824862506, 0.10703595470718086, -0.3621341824862506]
#COLLISION=False

R1x,R1y,R1theta,R1xpts,R1ypts = 0.595569815934045,1.969904716932111,304.18372957353085,[-0.11409165970506084, 0.001721962296423768, 0.1421840840572201, 0.02637046205573549], [0.04339462162232318, 0.12205340980836912, -0.08475662947999624, -0.16341541766604217]
R2x,R2y,R2theta,R2xpts,R2ypts = 0.8061781091873416,2.807738888095894,160.91167260229324,[0.34351635822898025, 0.23657545976510183, -0.34351635822898025, -0.23657545976510183], [0.05414401198595725, -0.25488647324204405, -0.05414401198595725, 0.25488647324204405]
COLLISION=True #True

# %%
R1xpts.append(R1xpts[0])
R1ypts.append(R1ypts[0])
R2xpts.append(R2xpts[0])
R2ypts.append(R2ypts[0])

R1xpoints = [x+R1x for x in R1xpts]
R1ypoints = [y+R1y for y in R1ypts]
R2xpoints = [x+R2x for x in R2xpts]
R2ypoints = [y+R2y for y in R2ypts]

# %%
fig, ax = plt.subplots()

plt.title(f"detection={COLLISION}")

ax.plot(R1xpoints, R1ypoints, color="red") 
ax.plot(R2xpoints, R2ypoints, color="blue")   

ax.set_aspect('equal', adjustable='datalim')
ax.grid(visible=True)
plt.show()

# %%
#R1p1,R1p2,R2p1R2p2 = (-4,3), (1,1), (0,2), (-3,1), (1,4)

#R1p1,R1p2,R2p1,R2p2 = [0.48147816, 2.01329934],[0.59729178, 2.09195813],[1.14969447 ,2.8618829 ],[1.04275357 ,2.55285241]
R1p1,R1p2,R2p1,R2p2 = [1.07704797, 3.98320406],[1.19286159, 4.06186284],[1.84893168, 5.3605913 ],[0.46266175, 2.75359488]

R1dx = R1p2[0] - R1p1[0]
R1dy = R1p2[1] - R1p1[1]
R2dx = R2p2[0] - R2p1[0]
R2dy = R2p2[1] - R2p1[1]
R1determinant = ( R2dy*(R2p2[0]-R1p1[0]) - R2dx*(R2p2[1]-R1p1[1]) ) * ( R2dy*(R2p2[0]-R1p2[0]) - R2dx*(R2p2[1]-R1p2[1]) )
R2determinant = ( R1dy*(R1p2[0]-R2p1[0]) - R1dx*(R1p2[1]-R2p1[1]) ) * ( R1dy*(R1p2[0]-R2p2[0]) - R1dx*(R1p2[1]-R2p2[1]) )

if (R1determinant <= 0) & (R2determinant <= 0): 
    print("COLLISION=True")
else:
    print("COLLISION=False")

R1xpoints = []

fig, ax = plt.subplots()
ax.plot([R1p1[0],R1p2[0]], [R1p1[1],R1p2[1]], color="red") 
ax.plot([R2p1[0],R2p2[0]], [R2p1[1],R2p2[1]], color="blue")   

ax.set_aspect('equal', adjustable='datalim')
ax.grid(visible=True)
plt.show()
# Out:
# COLLISION=True

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

R1x,R1y,R1theta,R1xpts,R1ypts = 0.595569815934045,1.969904716932111,304.18372957353085,[-0.11409165970506084, 0.001721962296423768, 0.1421840840572201, 0.02637046205573549], [0.04339462162232318, 0.12205340980836912, -0.08475662947999624, -0.16341541766604217]
R2x,R2y,R2theta,R2xpts,R2ypts = 4.860518789898071,0.49195654083284246,238.921609002914,[-0.17831914555451078, 0.3527204348339238, 0.17831914555451078, -0.3527204348339238], [0.3047127290346594, -0.015357726316361259, -0.3047127290346594, 0.015357726316361259]


def get_pts(p1,p2,p3,p4):
    Xpts = np.array([p1[0],p2[0],p3[0],p4[0]])
    Ypts = np.array([p1[1],p2[1],p3[1],p4[1]])
    #print(Xpts, Ypts )
    return Xpts, Ypts 
    
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(24,6))
# before rotation
#R1p1,R1p2,R1p3,R1p4,R2p1,R2p2,R2p3,R2p4 = (-0.1, -0.07),(-0.1, 0.07),(0.15, 0.07),(0.15, -0.07),(-0.16892463356511078, -0.3100194075891598),(-0.16892463356511078, 0.3100194075891598),(0.16892463356511078, 0.3100194075891598),(0.16892463356511078, -0.3100194075891598) #before
R1p1,R1p2,R1p3,R1p4,R2p1,R2p2,R2p3,R2p4 = (-0.1, -0.07),(-0.1, 0.07),(0.15, 0.07),(0.15, -0.07),(-0.16892463356511078, -0.3100194075891598),(-0.16892463356511078, 0.3100194075891598),(0.16892463356511078, 0.3100194075891598),(0.16892463356511078, -0.3100194075891598) #before rotation
R1Xpts,R1Ypts=get_pts(R1p1,R1p2,R1p3,R1p4)
R2Xpts,R2Ypts=get_pts(R2p1,R2p2,R2p3,R2p4)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)
ax1.set_title("before rotation")

# after rotation
#R1p1,R1p2,R1p3,R1p4,R2p1,R2p2,R2p3,R2p4 = (-0.11409165970506084, 0.04339462162232318),(0.001721962296423768, 0.12205340980836912),(0.1421840840572201, -0.08475662947999624),(0.02637046205573549, -0.16341541766604217),(-0.17831914555451078, 0.3047127290346594),(0.3527204348339238, -0.015357726316361259),(0.17831914555451078, -0.3047127290346594),(-0.3527204348339238, 0.015357726316361259) #before
R1p1,R1p2,R1p3,R1p4 = (-0.11409165970506084, 0.04339462162232318),(0.001721962296423768, 0.12205340980836912),(0.1421840840572201, -0.08475662947999624),(0.02637046205573549, -0.16341541766604217)
R2p1,R2p2,R2p3,R2p4 = (-0.17831914555451078, 0.3047127290346594),(0.3527204348339238, -0.015357726316361259),(0.17831914555451078, -0.3047127290346594),(-0.3527204348339238, 0.015357726316361259) #after rotation

R1Xpts,R1Ypts=get_pts(R1p1,R1p2,R1p3,R1p4)
R2Xpts,R2Ypts=get_pts(R2p1,R2p2,R2p3,R2p4)
ax2.plot(R1Xpts, R1Ypts, color="red") 
ax2.plot(R2Xpts, R2Ypts, color="blue") 
ax2.set_aspect('equal', adjustable='datalim')
ax2.grid(visible=True)
ax2.set_title(" afer rotation")
# translated afer rotation
ax3.plot(R1Xpts+R1x, R1Ypts+R1y, color="red") 
ax3.plot(R2Xpts+R2x, R2Ypts+R2y, color="blue") 
ax3.set_aspect('equal', adjustable='datalim')
ax3.grid(visible=True)
ax3.set_title("translated afer rotation")

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

def get_pts(p1,p2,p3,p4):
    Xpts = np.array([p1[0],p2[0],p3[0],p4[0]])
    Ypts = np.array([p1[1],p2[1],p3[1],p4[1]])
    #print(Xpts, Ypts )
    return Xpts, Ypts 


R1x,R1y,R1theta,R1xpts,R1ypts = 0.595569815934045,1.969904716932111,304.18372957353085,[0.48147815622898416, 0.5972917782304688, 0.7377538999912652, 0.6219402779897805], [2.013299338554434, 2.0919581267404803, 1.885148087452115, 1.8064892992660688]
R2x,R2y,R2theta,R2xpts,R2ypts = 0.7305246207518751,1.5640324694804737,296.408900831701,[0.39946070604364525, 0.7709173650661526, 1.061588535460105, 0.6901318764375975], [1.7644626327683053, 1.9489272501469388, 1.363602306192642, 1.1791376888140086]


fig, ax = plt.subplots(1,1, figsize=(8,6))
ax.plot(R1xpts, R1ypts, color="red") 
ax.plot(R2xpts,R2ypts, color="blue") 
ax.set_aspect('equal', adjustable='datalim')
ax.grid(visible=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(24,6))

def get_segments(s1p1,s1p2,s2p1,s2p2):
    s1Xpts = np.array([s1p1[0],s1p2[0]])
    s1Ypts = np.array([s1p1[1],s1p2[1]])
    s2Xpts = np.array([s2p1[0],s2p2[0]])
    s2Ypts = np.array([s2p1[1],s2p2[1]])
    return s1Xpts,s1Ypts,s2Xpts,s2Ypts

s1p1,s1p2,s2p1,s2p2 = (4.122542224785615, 3.558468970491852),(4.247056339615885, 3.4944671329554637),(4.191532632948925, 3.494489757209652),(4.065172073291873, 3.145473574876612) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.122542224785615, 3.558468970491852),(4.247056339615885, 3.4944671329554637),(4.065172073291873, 3.145473574876612),(3.398966083428994, 3.386672023507929) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.122542224785615, 3.558468970491852),(4.247056339615885, 3.4944671329554637),(3.398966083428994, 3.386672023507929),(3.525326643086047, 3.735688205840969) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.122542224785615, 3.558468970491852),(4.247056339615885, 3.4944671329554637),(3.525326643086047, 3.735688205840969),(4.191532632948925, 3.494489757209652) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.247056339615885, 3.4944671329554637),(4.132767344015192, 3.272120499329981),(4.191532632948925, 3.494489757209652),(4.065172073291873, 3.145473574876612) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.247056339615885, 3.4944671329554637),(4.132767344015192, 3.272120499329981),(4.065172073291873, 3.145473574876612),(3.398966083428994, 3.386672023507929) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.247056339615885, 3.4944671329554637),(4.132767344015192, 3.272120499329981),(3.398966083428994, 3.386672023507929),(3.525326643086047, 3.735688205840969) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.247056339615885, 3.4944671329554637),(4.132767344015192, 3.272120499329981),(3.525326643086047, 3.735688205840969),(4.191532632948925, 3.494489757209652) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

s1p1,s1p2,s2p1,s2p2 = (4.132767344015192, 3.272120499329981),(4.008253229184921, 3.33612233686637),(4.191532632948925, 3.494489757209652),(4.065172073291873, 3.145473574876612) #segments after translation
R1Xpts,R1Ypts,R2Xpts,R2Ypts = get_segments(s1p1,s1p2,s2p1,s2p2)
ax1.plot(R1Xpts,R1Ypts, color="red") 
ax1.plot(R2Xpts,R2Ypts, color="blue") 
ax1.set_aspect('equal', adjustable='datalim')
ax1.grid(visible=True)

# %%
2024-03-10T21:17:43.055309541Z R1p1,R1p2,R1p3,R1p4,R2p1,R2p2,R2p3,R2p4 = (-0.1, -0.07),(-0.1, 0.07),(0.15, 0.07),(0.15, -0.07),(-0.3542623013218212, -0.18559316162454204),(-0.3542623013218212, 0.18559316162454204),(0.3542623013218212, 0.18559316162454204),(0.3542623013218212, -0.18559316162454204) #before rotation
2024-03-10T21:17:43.055343151Z R1p1,R1p2,R1p3,R1p4,R2p1,R2p2,R2p3,R2p4 = (-0
id,x,y,theta,rad=10,4.222912877758452,4.595696288281338,105.15946328192481,0.632314071717887 # circle
id,x,y,theta,rad=11,3.2355403571152825,0.29613773330405657,42.627066457737754,0.6558937079554182 # circle
id,x,y,theta,rad=12,4.969798043700947,4.5885528122605805,168.44514707052483,0.3856963808546027 # circle
id,x,y,theta,rad=13,1.6286638047702002,0.1656936358886668,27.961694997623496,0.051825506231668136 # circle
id,x,y,theta,rad=14,2.313076662468342,2.2725081929613076,187.19446918695652,0.09086176658005223 # circle
id,x,y,theta,rad=15,2.6262370137952917,2.8474533720830966,231.56300689329953,0.14209181394096604 # circle
id,x,y,theta,dx,dy=16,4.860518789898071,0.49195654083284246,238.92160900291404,0.33784926713022156,0.6200388151783196 # Rectangle
id,x,y,theta,dx,dy=17,2.7621531199777483,2.706406851986568,37.147002135438576,0.4724922939977816,0.39464667693457695 # Rectangle
id,x,y,theta,dx,dy=18,3.045661801012084,3.9700994089184465,52.73353043543132,0.7706454009368824,0.4169544188357579 # Rectangle
id,x,y,theta,dx,dy=19,2.939307400147111,2.496197082156475,284.8974212631011,0.6117242255229307,0.6711083559558759 # Rectangle
id,x,y,theta,dx,dy=20,1.0773644638798363,2.042675235882046,315.66691027418307,0.34996404498410527,0.6079413001277422 # Rectangle
id,x,y,theta,dx,dy=21,1.248508249530308,0.27624439993147065,169.88056266665248,0.6997774479394674,0.35197585288166444 # Rectangle
id,x,y,theta,dx,dy=22,1.4223781648330798,2.1359962651829205,125.47794839309749,0.5157676912198356,0.4998433568174732 # Rectangle
id,x,y,theta,dx,dy=23,1.08623776245711,0.5192081301709589,145.9443853275983,0.7203741622825147,0.40796360737478055 # Rectangle
id,x,y,theta,dx,dy=24,3.093183438311899,0.7767598062739339,11.158169891038675,0.4696294041053247,0.7480675016585818 # Rectangle
id,x,y,theta,dx,dy=25,0.8061781091873416,2.807738888095894,160.91167260229324,0.6138436715115916,0.3270110037361365 # Rectangle
id,x,y,theta,dx,dy=26,0.12951612833220272,3.4402152232505885,288.66988629333036,0.755486354792564,0.3836997306568982 # Rectangle
id,x,y,theta,dx,dy=27,3.556277180220118,4.723164505923872,158.76443697275835,0.7743443364275329,0.4093009067977847 # Rectangle
id,x,y,theta,dx,dy=28,4.003123555587262,1.4676606955608618,8.730152470186114,0.6303568864341917,0.4393855274355535 # Rectangle
id,x,y,theta,dx,dy=29,1.4390237492778861,0.03698077273584843,32.844150093551406,0.7877862564679193,0.4177705403030527 # Rectangle
id,x,y,theta,dx,dy=30,0.5159244437882454,0.7361584271172822,22.375133300393905,0.7826130035447468,0.7317656521418974 # Rectangle
id,x,y,theta,dx,dy=31,0.7305246207518751,1.5640324694804737,296.408900831701,0.65352507167919,0.41473756111161303 # Rectangle
id,x,y,theta,dx,dy=32,2.5556131192298492,3.380984204250315,346.66654231261066,0.3464091039869021,0.7394863379779639 # Rectangle
id,x,y,theta,dx,dy=33,0.5513951109873161,4.207266065844786,150.4307230339107,0.6864102611498937,0.42065119563497805 # Rectangle
id,x,y,theta,dx,dy=34,4.8611774545906155,2.397929812257167,349.04959696907844,0.4442639238473984,0.3982991238283313 # Rectangle
# Out:
# [0.1 0.2] [0.5 0.6]
# [0.6 0.8] [0.5 0.6]
